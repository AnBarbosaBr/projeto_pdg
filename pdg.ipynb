# %% [markdown]
# # Projeto PDG

# %%
import pandas as pd;
import numpy as np; 
import sklearn.model_selection;
import sklearn.metrics;


from sklearn.tree import DecisionTreeClassifier; # Tree

# OBS: Scikit-Learn
# scikit-learn uses an optimised version of the CART algorithm; however, scikit-learn implementation does not support categorical variables for now.
# https://scikit-learn.org/stable/modules/tree.html



import statsmodels.api as sm; # GLM

# %%
seed = 42

# %%
data = pd.read_csv("data/car_insurance_claim.csv")

# %%
# Linhas / Colunas
forma = data.shape
print(f"{data.shape[0]} linhas e {data.shape[1]} colunas")
print(pd.DataFrame(data.columns))
print(data.describe())
print(data.describe().shape[1]) # Colunas Númericas
# Out:
# 10302 linhas e 27 colunas
#              0
# 0           ID
# 1     KIDSDRIV
# 2        BIRTH
# 3          AGE
# 4     HOMEKIDS
# 5          YOJ
# 6       INCOME
# 7      PARENT1
# 8     HOME_VAL
# 9      MSTATUS
# 10      GENDER
# 11   EDUCATION
# 12  OCCUPATION
# 13    TRAVTIME
# 14     CAR_USE
# 15    BLUEBOOK
# 16         TIF
# 17    CAR_TYPE
# 18     RED_CAR
# 19    OLDCLAIM
# 20    CLM_FREQ
# 21     REVOKED
# 22     MVR_PTS
# 23     CLM_AMT
# 24     CAR_AGE
# 25  CLAIM_FLAG
# 26  URBANICITY
#                  ID      KIDSDRIV           AGE      HOMEKIDS          YOJ  \
# count  1.030200e+04  10302.000000  10295.000000  10302.000000  9754.000000
# mean   4.956631e+08      0.169288     44.837397      0.720443    10.474062
# std    2.864675e+08      0.506512      8.606445      1.116323     4.108943
# min    6.317500e+04      0.000000     16.000000      0.000000     0.000000
# 25%    2.442869e+08      0.000000     39.000000      0.000000     9.000000
# 50%    4.970043e+08      0.000000     45.000000      0.000000    11.000000
# 75%    7.394551e+08      0.000000     51.000000      1.000000    13.000000
# max    9.999264e+08      4.000000     81.000000      5.000000    23.000000
#
#            TRAVTIME           TIF      CLM_FREQ       MVR_PTS      CAR_AGE  \
# count  10302.000000  10302.000000  10302.000000  10302.000000  9663.000000
# mean      33.416424      5.329159      0.800718      1.710153     8.298148
# std       15.869687      4.110795      1.154079      2.159015     5.714450
# min        5.000000      1.000000      0.000000      0.000000    -3.000000
# 25%       22.000000      1.000000      0.000000      0.000000     1.000000
# 50%       33.000000      4.000000      0.000000      1.000000     8.000000
# 75%       44.000000      7.000000      2.000000      3.000000    12.000000
# max      142.000000     25.000000      5.000000     13.000000    28.000000
#
#          CLAIM_FLAG
# count  10302.000000
# mean       0.266550
# std        0.442177
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# 11

# %%
def score_results(y_real, y_predito, label):
    matriz_de_confusao = sklearn.metrics.confusion_matrix(y_true = y_real, y_pred = y_predito)
    tn, fp, fn, tp = matriz_de_confusao.ravel()
    
    print(f"--- {label} ---")
    print("Matrix de Confusão")
    print(matriz_de_confusao)
    print("Balanced Accuracy: ", end=" ")
    print(f"{100*sklearn.metrics.balanced_accuracy_score(y_true = y_real, y_pred = y_predito):.2f}%")
    print(f"Falsos Positivos: {fp}, Falsos Negativos: {fn}\n"+
            f"Verdadeiros Positivos: {tp}, Verdadeiros Negativos: {tn}")
    print(f"Precisao (tp/(tp+fp)): {100*tp/(tp+fp) :.2f}%")
    print(f"Recall (tp/(tp+fn)): {100*tp/(tp+fn) :.2f}%")
    
    print("-"*50)

# %%
## Decision Tree
independent_variables = list(range(1,25))
dependent_variables = 25
cartTree = DecisionTreeClassifier()

X_data = data.iloc[ : , independent_variables]
y_data = data.iloc[ : , dependent_variables]

stratified_k_fold = sklearn.model_selection.StratifiedKFold(n_splits = 5, random_state = seed )

pastas = stratified_k_fold.split(X_data, y_data)

for i, (train, test) in enumerate(pastas):
    print("-"*80)
    print(f"K Fold - Rodada {i}\n")
    X_train = X_data.iloc[train, : ]
    y_train = y_data.iloc[train]

    X_test = X_data.iloc[test, : ]
    y_test = y_data.iloc[test]
    
    # Improve this part
    numerical_x_train = X_train._get_numeric_data()
    numerical_x_train.fillna(numerical_x_train.mean(), inplace=True)
    
    fit_result = cartTree.fit(numerical_x_train, y_train)
    print(fit_result)
    print("-"*50)
    
    predicted_train = cartTree.predict(numerical_x_train)
    score_results(y_train, predicted_train, "CART Tree - Treinamento")
    
    # Improve this part
    numerical_x_test = X_test._get_numeric_data()
    numerical_x_test.fillna(numerical_x_test.mean(), inplace=True)
    
    predicted_test = cartTree.predict(numerical_x_test)
    score_results(y_test, predicted_test, "CART Tree - Teste")
# Out:
# --------------------------------------------------------------------------------
# K Fold - Rodada 0
#
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')
# --------------------------------------------------
# --- CART Tree - Treinamento ---
# Matrix de Confusão
# [[6044    0]
#  [   2 2194]]
# Balanced Accuracy:  99.95%
# Falsos Positivos: 0, Falsos Negativos: 2
# Verdadeiros Positivos: 2194, Verdadeiros Negativos: 6044
# Precisao (tp/(tp+fp)): 100.00%
# Recall (tp/(tp+fn)): 99.91%
# --------------------------------------------------
# --- CART Tree - Teste ---
# Matrix de Confusão
# [[1129  383]
#  [ 352  198]]
# Balanced Accuracy:  55.33%
# Falsos Positivos: 383, Falsos Negativos: 352
# Verdadeiros Positivos: 198, Verdadeiros Negativos: 1129
# Precisao (tp/(tp+fp)): 34.08%
# Recall (tp/(tp+fn)): 36.00%
# --------------------------------------------------
# --------------------------------------------------------------------------------
# K Fold - Rodada 1
#
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')
# --------------------------------------------------
# --- CART Tree - Treinamento ---
# Matrix de Confusão
# [[6045    0]
#  [   3 2194]]
# Balanced Accuracy:  99.93%
# Falsos Positivos: 0, Falsos Negativos: 3
# Verdadeiros Positivos: 2194, Verdadeiros Negativos: 6045
# Precisao (tp/(tp+fp)): 100.00%
# Recall (tp/(tp+fn)): 99.86%
# --------------------------------------------------
# --- CART Tree - Teste ---
# Matrix de Confusão
# [[1128  383]
#  [ 327  222]]
# Balanced Accuracy:  57.54%
# Falsos Positivos: 383, Falsos Negativos: 327
# Verdadeiros Positivos: 222, Verdadeiros Negativos: 1128
# Precisao (tp/(tp+fp)): 36.69%
# Recall (tp/(tp+fn)): 40.44%
# --------------------------------------------------
# --------------------------------------------------------------------------------
# K Fold - Rodada 2
#
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')
# --------------------------------------------------
# --- CART Tree - Treinamento ---
# Matrix de Confusão
# [[6045    0]
#  [   2 2195]]
# Balanced Accuracy:  99.95%
# Falsos Positivos: 0, Falsos Negativos: 2
# Verdadeiros Positivos: 2195, Verdadeiros Negativos: 6045
# Precisao (tp/(tp+fp)): 100.00%
# Recall (tp/(tp+fn)): 99.91%
# --------------------------------------------------
# --- CART Tree - Teste ---
# Matrix de Confusão
# [[1111  400]
#  [ 322  227]]
# Balanced Accuracy:  57.44%
# Falsos Positivos: 400, Falsos Negativos: 322
# Verdadeiros Positivos: 227, Verdadeiros Negativos: 1111
# Precisao (tp/(tp+fp)): 36.20%
# Recall (tp/(tp+fn)): 41.35%
# --------------------------------------------------
# --------------------------------------------------------------------------------
# K Fold - Rodada 3
#
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')
# --------------------------------------------------
# --- CART Tree - Treinamento ---
# Matrix de Confusão
# [[6045    0]
#  [   2 2195]]
# Balanced Accuracy:  99.95%
# Falsos Positivos: 0, Falsos Negativos: 2
# Verdadeiros Positivos: 2195, Verdadeiros Negativos: 6045
# Precisao (tp/(tp+fp)): 100.00%
# Recall (tp/(tp+fn)): 99.91%
# --------------------------------------------------
# --- CART Tree - Teste ---
# Matrix de Confusão
# [[1157  354]
#  [ 348  201]]
# Balanced Accuracy:  56.59%
# Falsos Positivos: 354, Falsos Negativos: 348
# Verdadeiros Positivos: 201, Verdadeiros Negativos: 1157
# Precisao (tp/(tp+fp)): 36.22%
# Recall (tp/(tp+fn)): 36.61%
# --------------------------------------------------
# --------------------------------------------------------------------------------
# K Fold - Rodada 4
#
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')
# --------------------------------------------------
# --- CART Tree - Treinamento ---
# Matrix de Confusão
# [[6045    0]
#  [   3 2194]]
# Balanced Accuracy:  99.93%
# Falsos Positivos: 0, Falsos Negativos: 3
# Verdadeiros Positivos: 2194, Verdadeiros Negativos: 6045
# Precisao (tp/(tp+fp)): 100.00%
# Recall (tp/(tp+fn)): 99.86%
# --------------------------------------------------
# --- CART Tree - Teste ---
# Matrix de Confusão
# [[1142  369]
#  [ 340  209]]
# Balanced Accuracy:  56.82%
# Falsos Positivos: 369, Falsos Negativos: 340
# Verdadeiros Positivos: 209, Verdadeiros Negativos: 1142
# Precisao (tp/(tp+fp)): 36.16%
# Recall (tp/(tp+fn)): 38.07%
# --------------------------------------------------

# %%
## GLM
independent_variables = list(range(1,25))
dependent_variables = 25

X_data = data.iloc[ : , independent_variables]
y_data = data.iloc[ : , dependent_variables]

stratified_k_fold = sklearn.model_selection.StratifiedKFold(n_splits = 5, random_state = seed )

pastas = stratified_k_fold.split(X_data, y_data)

for i, (train, test) in enumerate(pastas):
    print("-"*80)
    print(f"K Fold - Rodada {i}\n")
    X_train = X_data.iloc[train, : ]
    y_train = y_data.iloc[train]

    X_test = X_data.iloc[test, : ]
    y_test = y_data.iloc[test]
    
    # Improve this part
    numerical_x_train = X_train._get_numeric_data()
    numerical_x_train.fillna(numerical_x_train.mean(), inplace=True)    
    #################################################
    
    glm = sm.GLM(exog = numerical_x_train, endog =  y_train, family=sm.families.Binomial())
    
    predictor_glm = glm.fit()
    print(predictor_glm.summary())
    print("-"*50)

 
    treshold = 0.5
    predicted_train_probs = predictor_glm.predict(numerical_x_train)
    
    predicted_train = (predicted_train_probs > treshold)
    score_results(y_train, predicted_train, "GLM - Treinamento")

    # Improve this part
    numerical_x_test = X_test._get_numeric_data()
    numerical_x_test.fillna(numerical_x_test.mean(), inplace=True)
    ######################################################
    predicted_test_probs = predictor_glm.predict(numerical_x_test)
    predicted_test =  (predicted_test_probs > treshold )
    
    score_results(y_test, predicted_test, "GLM - Teste")
# Out:
# --------------------------------------------------------------------------------
# K Fold - Rodada 0
#
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:             CLAIM_FLAG   No. Observations:                 8240
# Model:                            GLM   Df Residuals:                     8231
# Model Family:                Binomial   Df Model:                            8
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -4351.4
# Date:                Thu, 21 Nov 2019   Deviance:                       8702.8
# Time:                        09:33:30   Pearson chi2:                 8.18e+03
# No. Iterations:                     4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# KIDSDRIV       0.3404      0.053      6.412      0.000       0.236       0.445
# AGE           -0.0225      0.002    -10.882      0.000      -0.027      -0.018
# HOMEKIDS       0.0383      0.026      1.471      0.141      -0.013       0.089
# YOJ           -0.0357      0.006     -5.601      0.000      -0.048      -0.023
# TRAVTIME       0.0068      0.002      4.359      0.000       0.004       0.010
# TIF           -0.0440      0.007     -6.697      0.000      -0.057      -0.031
# CLM_FREQ       0.3048      0.023     13.237      0.000       0.260       0.350
# MVR_PTS        0.1432      0.012     11.699      0.000       0.119       0.167
# CAR_AGE       -0.0361      0.005     -7.299      0.000      -0.046      -0.026
# ==============================================================================
# --------------------------------------------------
# --- GLM - Treinamento ---
# Matrix de Confusão
# [[5733  311]
#  [1793  403]]
# Balanced Accuracy:  56.60%
# Falsos Positivos: 311, Falsos Negativos: 1793
# Verdadeiros Positivos: 403, Verdadeiros Negativos: 5733
# Precisao (tp/(tp+fp)): 56.44%
# Recall (tp/(tp+fn)): 18.35%
# --------------------------------------------------
# --- GLM - Teste ---
# Matrix de Confusão
# [[1425   87]
#  [ 441  109]]
# Balanced Accuracy:  57.03%
# Falsos Positivos: 87, Falsos Negativos: 441
# Verdadeiros Positivos: 109, Verdadeiros Negativos: 1425
# Precisao (tp/(tp+fp)): 55.61%
# Recall (tp/(tp+fn)): 19.82%
# --------------------------------------------------
# --------------------------------------------------------------------------------
# K Fold - Rodada 1
#
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:             CLAIM_FLAG   No. Observations:                 8242
# Model:                            GLM   Df Residuals:                     8233
# Model Family:                Binomial   Df Model:                            8
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -4365.1
# Date:                Thu, 21 Nov 2019   Deviance:                       8730.1
# Time:                        09:33:30   Pearson chi2:                 8.19e+03
# No. Iterations:                     4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# KIDSDRIV       0.2919      0.054      5.367      0.000       0.185       0.398
# AGE           -0.0217      0.002    -10.622      0.000      -0.026      -0.018
# HOMEKIDS       0.0610      0.026      2.362      0.018       0.010       0.112
# YOJ           -0.0323      0.006     -5.113      0.000      -0.045      -0.020
# TRAVTIME       0.0056      0.002      3.579      0.000       0.003       0.009
# TIF           -0.0496      0.007     -7.475      0.000      -0.063      -0.037
# CLM_FREQ       0.3184      0.023     13.934      0.000       0.274       0.363
# MVR_PTS        0.1312      0.012     10.683      0.000       0.107       0.155
# CAR_AGE       -0.0359      0.005     -7.298      0.000      -0.046      -0.026
# ==============================================================================
# --------------------------------------------------
# --- GLM - Treinamento ---
# Matrix de Confusão
# [[5734  311]
#  [1796  401]]
# Balanced Accuracy:  56.55%
# Falsos Positivos: 311, Falsos Negativos: 1796
# Verdadeiros Positivos: 401, Verdadeiros Negativos: 5734
# Precisao (tp/(tp+fp)): 56.32%
# Recall (tp/(tp+fn)): 18.25%
# --------------------------------------------------
# --- GLM - Teste ---
# Matrix de Confusão
# [[1432   79]
#  [ 451   98]]
# Balanced Accuracy:  56.31%
# Falsos Positivos: 79, Falsos Negativos: 451
# Verdadeiros Positivos: 98, Verdadeiros Negativos: 1432
# Precisao (tp/(tp+fp)): 55.37%
# Recall (tp/(tp+fn)): 17.85%
# --------------------------------------------------
# --------------------------------------------------------------------------------
# K Fold - Rodada 2
#
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:             CLAIM_FLAG   No. Observations:                 8242
# Model:                            GLM   Df Residuals:                     8233
# Model Family:                Binomial   Df Model:                            8
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -4349.2
# Date:                Thu, 21 Nov 2019   Deviance:                       8698.3
# Time:                        09:33:30   Pearson chi2:                 8.20e+03
# No. Iterations:                     4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# KIDSDRIV       0.3471      0.053      6.492      0.000       0.242       0.452
# AGE           -0.0212      0.002    -10.276      0.000      -0.025      -0.017
# HOMEKIDS       0.0699      0.026      2.725      0.006       0.020       0.120
# YOJ           -0.0291      0.006     -4.555      0.000      -0.042      -0.017
# TRAVTIME       0.0047      0.002      2.964      0.003       0.002       0.008
# TIF           -0.0544      0.007     -8.207      0.000      -0.067      -0.041
# CLM_FREQ       0.2911      0.023     12.606      0.000       0.246       0.336
# MVR_PTS        0.1452      0.012     11.846      0.000       0.121       0.169
# CAR_AGE       -0.0383      0.005     -7.778      0.000      -0.048      -0.029
# ==============================================================================
# --------------------------------------------------
# --- GLM - Treinamento ---
# Matrix de Confusão
# [[5728  317]
#  [1783  414]]
# Balanced Accuracy:  56.80%
# Falsos Positivos: 317, Falsos Negativos: 1783
# Verdadeiros Positivos: 414, Verdadeiros Negativos: 5728
# Precisao (tp/(tp+fp)): 56.63%
# Recall (tp/(tp+fn)): 18.84%
# --------------------------------------------------
# --- GLM - Teste ---
# Matrix de Confusão
# [[1429   82]
#  [ 445  104]]
# Balanced Accuracy:  56.76%
# Falsos Positivos: 82, Falsos Negativos: 445
# Verdadeiros Positivos: 104, Verdadeiros Negativos: 1429
# Precisao (tp/(tp+fp)): 55.91%
# Recall (tp/(tp+fn)): 18.94%
# --------------------------------------------------
# --------------------------------------------------------------------------------
# K Fold - Rodada 3
#
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:             CLAIM_FLAG   No. Observations:                 8242
# Model:                            GLM   Df Residuals:                     8233
# Model Family:                Binomial   Df Model:                            8
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -4386.5
# Date:                Thu, 21 Nov 2019   Deviance:                       8773.1
# Time:                        09:33:30   Pearson chi2:                 8.20e+03
# No. Iterations:                     4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# KIDSDRIV       0.2618      0.053      4.924      0.000       0.158       0.366
# AGE           -0.0207      0.002    -10.146      0.000      -0.025      -0.017
# HOMEKIDS       0.0560      0.026      2.160      0.031       0.005       0.107
# YOJ           -0.0320      0.006     -5.083      0.000      -0.044      -0.020
# TRAVTIME       0.0058      0.002      3.719      0.000       0.003       0.009
# TIF           -0.0530      0.007     -8.034      0.000      -0.066      -0.040
# CLM_FREQ       0.2937      0.023     12.694      0.000       0.248       0.339
# MVR_PTS        0.1331      0.012     10.903      0.000       0.109       0.157
# CAR_AGE       -0.0376      0.005     -7.665      0.000      -0.047      -0.028
# ==============================================================================
# --------------------------------------------------
# --- GLM - Treinamento ---
# Matrix de Confusão
# [[5754  291]
#  [1818  379]]
# Balanced Accuracy:  56.22%
# Falsos Positivos: 291, Falsos Negativos: 1818
# Verdadeiros Positivos: 379, Verdadeiros Negativos: 5754
# Precisao (tp/(tp+fp)): 56.57%
# Recall (tp/(tp+fn)): 17.25%
# --------------------------------------------------
# --- GLM - Teste ---
# Matrix de Confusão
# [[1447   64]
#  [ 454   95]]
# Balanced Accuracy:  56.53%
# Falsos Positivos: 64, Falsos Negativos: 454
# Verdadeiros Positivos: 95, Verdadeiros Negativos: 1447
# Precisao (tp/(tp+fp)): 59.75%
# Recall (tp/(tp+fn)): 17.30%
# --------------------------------------------------
# --------------------------------------------------------------------------------
# K Fold - Rodada 4
#
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:             CLAIM_FLAG   No. Observations:                 8242
# Model:                            GLM   Df Residuals:                     8233
# Model Family:                Binomial   Df Model:                            8
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -4344.2
# Date:                Thu, 21 Nov 2019   Deviance:                       8688.3
# Time:                        09:33:30   Pearson chi2:                 8.20e+03
# No. Iterations:                     4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# KIDSDRIV       0.2958      0.054      5.469      0.000       0.190       0.402
# AGE           -0.0224      0.002    -10.902      0.000      -0.026      -0.018
# HOMEKIDS       0.0881      0.026      3.398      0.001       0.037       0.139
# YOJ           -0.0344      0.006     -5.451      0.000      -0.047      -0.022
# TRAVTIME       0.0068      0.002      4.289      0.000       0.004       0.010
# TIF           -0.0510      0.007     -7.726      0.000      -0.064      -0.038
# CLM_FREQ       0.2890      0.023     12.470      0.000       0.244       0.334
# MVR_PTS        0.1471      0.012     11.967      0.000       0.123       0.171
# CAR_AGE       -0.0367      0.005     -7.415      0.000      -0.046      -0.027
# ==============================================================================
# --------------------------------------------------
# --- GLM - Treinamento ---
# Matrix de Confusão
# [[5719  326]
#  [1766  431]]
# Balanced Accuracy:  57.11%
# Falsos Positivos: 326, Falsos Negativos: 1766
# Verdadeiros Positivos: 431, Verdadeiros Negativos: 5719
# Precisao (tp/(tp+fp)): 56.94%
# Recall (tp/(tp+fn)): 19.62%
# --------------------------------------------------
# --- GLM - Teste ---
# Matrix de Confusão
# [[1434   77]
#  [ 453   96]]
# Balanced Accuracy:  56.20%
# Falsos Positivos: 77, Falsos Negativos: 453
# Verdadeiros Positivos: 96, Verdadeiros Negativos: 1434
# Precisao (tp/(tp+fp)): 55.49%
# Recall (tp/(tp+fn)): 17.49%
# --------------------------------------------------

# %%
# RBFN
## Setup

## Train
## Test


# Compare results

# %%
# ?sm.GLM
